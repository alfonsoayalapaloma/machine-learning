# %% [markdown]
# <a href="https://colab.research.google.com/github/alfonsoayalapaloma/machine-learning/blob/main/ml_09_llm_ollama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://pandas.pydata.org/static/img/pandas.svg" width="250">
#
#
# ## <center> LLM - OLLAMA

# %% [markdown]
# # Solución de un problema usando LLMs

# %% [markdown]
# Ollama es una plataforma avanzada de modelos de lenguaje diseñada para simplificar el despliegue y la gestión de aplicaciones de PLN (Procesamiento de Lenguaje Natural). Es fundamental para desarrolladores e investigadores que buscan aprovechar tecnologías de PLN de vanguardia con facilidad y eficiencia. Este tutorial te guiará en la ejecución de LLaMA3 en Ollama dentro de un entorno de Google Colab, cubriendo los pasos de configuración, integración y ejecución para realizar consultas simples.

# %% [markdown]
# # Problema de Lenguaje natural

# %% [markdown]
# 1. Análisis del problema

# %% [markdown]
# Usted es un ingeniero de Machine Learning y se le pide desarrollar chatbot que responda a preguntas simples de cultura general.
# Este es un problema de Lenguaje Natural e Inteligencia Artificial Generativa, por lo que se puede usar un LLM.
#
# Se puede utilizar un entorno como OLLAMA

# %% [markdown]
# 2. Instalar OLLAMA

# %%
# Install ollama: The Ollama API is now available at 127.0.0.1:11434
! curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %% [markdown]
# Iniciar el servidor OLLAMA y descargar el modelo llama3

# %%
# serve ollama locally
import subprocess
process = subprocess.Popen("ollama serve", shell=True)
# credit: https://stackoverflow.com/questions/78437376/run-ollama-run-llama3-in-colab-raise-err-error-could-not-connect-to-ollama

# download the llama3 model
# !ollama pull llama3 #download llama3 model

# %% [markdown]
# Correr el modelo en el servidor OLLAMA y hacerle la pregunta: "

# %%
# !ollama run llama3 #run ollama model # type out your questions in the shell
# Out:
# >>> Send a message (/? for help)que
# ... es l
# ... a in
# ... teli
# ... genc
# ... ia a
# ... rtif
# ... icia
# ... l
# La inteligencia artificial (IA) se refiere al campo de estudio y aplicación que combina la computación, el procesamiento de lenguaje natural, las matemáticas y la ingeniería para crear sistemas que pueden realizar tareas que habitualmente requieren la inteligencia humana, como:
#
# 1. Aprendizaje automático: capacidad de aprender a partir de datos y mejorar su desempeño sin necesidad de ser programados explícitamente.
# 2. Reconocimiento de patrones: capacidad para detectar y analizar patrones en datos, como imágenes o texto.
# 3. Tomada de decisiones: capacidad para tomar decisiones basadas en la información disponible y los objetivos definidos.
# 4. Comunicación natural: capacidad para interactuar con humanos a través de interfaces como voz, texto o gestos.
#
# La IA se puede dividir en dos categorías principales:
#
# ...

# %% [markdown]
# # EJERCICIO
#
# Preguntar algo nuevo al LLM
